# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# # Grabbing Features

# %%
def build_data(file_names,directory):
    df_Final = pd.DataFrame(columns=['PDB code','VDWAALS','EEL','EGB','ESURF','GGAS','GSOLV','TOTAL'])
    for file in file_names:
        df = pd.read_csv(directory+"/"+file,delimiter='\t')
        df = df.iloc[83:92, :]
        df.drop([85,86],axis = 0,inplace=True)
        l1 = [file[:4]]
        for _,row in df.iterrows():
            val = float(row.iloc[0].split()[1])
            l1.append(val)
        df_Final.loc[len(df_Final.index)] = l1
    return df_Final

def create_pairs(df):
    df_Final = pd.DataFrame(columns=["PDB code 1","VDWAALS 1","EEL 1","EGB 1","ESURF 1","GGAS 1","GSOLV 1","TOTAL 1","PDB code 2","VDWAALS 2","EEL 2","EGB 2","ESURF 2","GGAS 2","GSOLV 2","TOTAL 2"])
    for _ , row1 in df.iterrows():
        for _ , row2 in df.iterrows():
            if row1["PDB code"] == row2["PDB code"]:
                continue
            temp = row1.to_list() + row2.to_list()
            df_Final.loc[len(df_Final.index)] = temp
    return df_Final

# %%
directory = "complex_data_raw"
df_features = build_data(os.listdir(directory),directory)
df_features = create_pairs(df_features)

# %% [markdown]
# # Complexes still missing

# %%
test = pd.read_csv("Aptamer-Protein-Information.csv")
for code in test["Unnamed: 0"]:
    if code not in set(df_features["PDB code 1"]):
        print(code)
# Out:
# nan
# 1knz
# 1rpu
# 2ccz
# 2kz5
# 2la5
# 3v7e
# 4hj5
# 4kze
# 4mdx
# 4s0n
# 5wwf
# 5wzh

# %%
df_features
# Out:
#      PDB code 1  VDWAALS 1   EEL 1   EGB 1  ESURF 1  GGAS 1  GSOLV 1  TOTAL 1  \
# 0          4him    -114.69 -645.74  676.69   -13.70 -760.43   663.00   -97.43
# 1          4him    -114.69 -645.74  676.69   -13.70 -760.43   663.00   -97.43
# 2          4him    -114.69 -645.74  676.69   -13.70 -760.43   663.00   -97.43
# 3          4him    -114.69 -645.74  676.69   -13.70 -760.43   663.00   -97.43
# 4          4him    -114.69 -645.74  676.69   -13.70 -760.43   663.00   -97.43
# ...         ...        ...     ...     ...      ...     ...      ...      ...
# 2157       2err     -97.46 -560.92  590.08   -11.74 -658.38   578.34   -80.04
# 2158       2err     -97.46 -560.92  590.08   -11.74 -658.38   578.34   -80.04
# 2159       2err     -97.46 -560.92  590.08   -11.74 -658.38   578.34   -80.04
# 2160       2err     -97.46 -560.92  590.08   -11.74 -658.38   578.34   -80.04
# 2161       2err     -97.46 -560.92  590.08   -11.74 -658.38   578.34   -80.04
#
#      PDB code 2  VDWAALS 2     EEL 2     EGB 2  ESURF 2    GGAS 2   GSOLV 2  \
# 0          1u63    -279.25 -34181.81  34208.24   -41.36 -34461.07  34166.88
# 1          2kh9     -49.13   -508.76    534.32    -5.94   -557.89    528.38
# 2          1wwe     -89.90  -1356.54   1369.99   -11.95  -1446.44   1358.04
# 3          1osb    -563.32 -11193.39  11154.77   -72.18 -11756.71  11082.59
# 4          5yts     -57.48   -136.57    171.71    -7.00   -194.05    164.71
# ...         ...        ...       ...       ...      ...       ...       ...
# 2157       5wwe     -78.63  -1194.77   1191.48   -10.79  -1273.40   1180.70
# 2158       1wwf    -109.69  -1452.29   1473.77   -14.75  -1561.98   1459.02
# 2159       2mki     -85.56   -260.76    305.67   -10.57   -346.32    295.11
# 2160       5ytv     -45.47   -179.99    205.21    -5.59   -225.46    199.61
# 2161       1rkj    -119.28   -801.67    834.16   -15.17   -920.95    818.99
#
#       TOTAL 2
# 0     -294.19
# 1      -29.51
# 2      -88.40
# 3     -674.11
# 4      -29.34
# ...       ...
# 2157   -92.70
# 2158  -102.95
# 2159   -51.21
# 2160   -25.84
# 2161  -101.96
#
# [2162 rows x 16 columns]

# %% [markdown]
# # Data outputs

# %%
def translate_kd(kd):
    kd.strip()
    kd = kd[3:]
    factor = 0
    if "nM" in kd:
        factor = 1
    elif "pM" in kd:
        factor = .001
    elif "uM" in kd:
        factor = 1000
    kd = kd[:-2]
    try:
        return float(kd) * factor
    except:
        print(kd)
        return None
    
def output(df):
    df_Final = pd.DataFrame(columns=["PDB code 1","Protein Name 1","Ligand Name 1","Affinity Data 1","kd value (nM) 1","PDB code 2","Protein Name 2","Ligand Name 2","Affinity Data 2","kd value (nM) 2","Output"])
    for _ , row1 in df.iterrows():
        for _ , row2 in df.iterrows():
            if row1["PDB code"] == row2["PDB code"]:
                continue
            output = 1 if row1["kd value (nM)"] < row2["kd value (nM)"] else 0
            temp = row1.to_list() + row2.to_list()
            temp.append(output)
            df_Final.loc[len(df_Final.index)] = temp
    return df_Final

# %%
df = pd.read_csv("KD_data.csv")
df.columns = df.iloc[0]
df.drop(index = 0,inplace=True)
df = df[['PDB code','Protein Name','Ligand Name','Affinity Data']]
df["kd value (nM)"] = [translate_kd(kd) for kd in df["Affinity Data"]]
df = df[df["PDB code"].isin(df_features["PDB code 1"])]
df_outputs = output(df)
# Out:
# 0=4.9
# 0=0.03
# 0=0.3
# 0=4.6
# 0=4
# 0=0.25
# 0=126

# %%
df_outputs
# Out:
#      PDB code 1                                     Protein Name 1  \
# 0          1exd                         GLUTAMINYL-TRNA SYNTHETASE
# 1          1exd                         GLUTAMINYL-TRNA SYNTHETASE
# 2          1exd                         GLUTAMINYL-TRNA SYNTHETASE
# 3          1exd                         GLUTAMINYL-TRNA SYNTHETASE
# 4          1exd                         GLUTAMINYL-TRNA SYNTHETASE
# ...         ...                                                ...
# 2157       5yts  Nuclease-sensitive element-binding protein 1, ...
# 2158       5yts  Nuclease-sensitive element-binding protein 1, ...
# 2159       5yts  Nuclease-sensitive element-binding protein 1, ...
# 2160       5yts  Nuclease-sensitive element-binding protein 1, ...
# 2161       5yts  Nuclease-sensitive element-binding protein 1, ...
#
#                Ligand Name 1 Affinity Data 1  kd value (nM) 1 PDB code 2  \
# 0     GLUTAMINE TRNA APTAMER        Kd=7.1nM              7.1       1il2
# 1     GLUTAMINE TRNA APTAMER        Kd=7.1nM              7.1       1jbr
# 2     GLUTAMINE TRNA APTAMER        Kd=7.1nM              7.1       1je8
# 3     GLUTAMINE TRNA APTAMER        Kd=7.1nM              7.1       1omh
# 4     GLUTAMINE TRNA APTAMER        Kd=7.1nM              7.1       1osb
# ...                      ...             ...              ...        ...
# 2157        RNA A2U (UCUUCU)       Kd=2.77uM           2770.0       6eo6
# 2158        RNA A2U (UCUUCU)       Kd=2.77uM           2770.0       6eo7
# 2159        RNA A2U (UCUUCU)       Kd=2.77uM           2770.0       5ytx
# 2160        RNA A2U (UCUUCU)       Kd=2.77uM           2770.0       5ytv
# 2161        RNA A2U (UCUUCU)       Kd=2.77uM           2770.0       5ytt
#
#                                          Protein Name 2  \
# 0                              ASPARTYL-TRNA SYNTHETASE
# 1     Ribotoxin Restrictocin and a 31-mer SRD RNA In...
# 2       Nitrate/Nitrite Response Regulator Protein NARL
# 3                                          trwC protein
# 4                                          trwC protein
# ...                                                 ...
# 2157                               human alpha-thrombin
# 2158                               human alpha-thrombin
# 2159  Nuclease-sensitive element-binding protein 1, ...
# 2160  Nuclease-sensitive element-binding protein 1, ...
# 2161  Nuclease-sensitive element-binding protein 1, ...
#
#                         Ligand Name 2 Affinity Data 2  kd value (nM) 2  Output
# 0               ASPARTYL TRANSFER RNA          Kd=3uM          3000.00       1
# 1                                 RNA          Kd=1uM          1000.00       1
# 2                                 DNA       Kd=0.15nM             0.15       0
# 3                 DNA OLIGONUCLEOTIDE         Kd=70nM            70.00       1
# 4                 DNA OLIGONUCLEOTIDE         Kd=70nM            70.00       1
# ...                               ...             ...              ...     ...
# 2157  modified 15-mer DNA aptamer T4W          Kd=1nM             1.00       0
# 2158  modified 15-mer DNA aptamer T4K       Kd=0.39nM             0.39       0
# 2159                 RNA U3A (UCAACU)       Kd=1.34uM          1340.00       0
# 2160                 RNA CAUC(UCAUCU)       Kd=1.26uM          1260.00       0
# 2161                 RNA C4G (UCAUGU)       Kd=3.77uM          3770.00       1
#
# [2162 rows x 11 columns]

# %% [markdown]
# # More features

# %%
def read_file1(complex,file):
    try:
        _,y = np.loadtxt("hbond_analysis/" + complex+'/'+file,comments = ['@','#'],unpack=True)
        return np.mean(y), np.std(y)
    except:
        return None,None

def read_file2(complex,file):
    try:
        _,y,_ = np.loadtxt("hbond_analysis/" + complex+'/'+file,comments = ['@','#'],unpack=True)
        return np.mean(y), np.std(y)
    except:
        return None,None

def read_file3(complex,file):
    try:
        _,y,z = np.loadtxt("hbond_analysis/" + complex+'/'+file,comments = ['@','#'],unpack=True)
        return np.mean(y), np.std(y), np.mean(z), np.mean(y)
    except:
        return None,None

# %%
l1 = os.listdir("hbond_analysis")
#df_extra_features = pd.DataFrame(columns=['PDB code','hbdist_mean','hbdist_std','hblife_mean','hblife_std','hbnum_mean1','hbnum_std1','hbnum_mean2','hbnum_std2'])
df_extra_features = pd.DataFrame(columns=['PDB code','hbdist_mean','hbdist_std','hbnum_mean1','hbnum_std1','hbnum_mean2','hbnum_std2'])
for complex in l1:
    l2 = os.listdir("hbond_analysis/" + complex)
    l1 = [complex]
    for file in l2:
        if file == 'hbdist.xvg':
            mean, std = read_file1(complex,file)
            l1 += [mean,std]
        elif file == 'hblife.xvg':
            #mean, std = read_file2(complex,file)
            #l1 += [mean,std]
            continue
        elif file == 'hbnum.xvg':
            mean1, std1, mean2, std2 = read_file3(complex,file)
            l1 += [mean1,std1,mean2,std2]
    df_extra_features.loc[len(df_extra_features.index)] = l1

# %%
df_extra_features
# Out:
#    PDB code  hbdist_mean  hbdist_std  hbnum_mean1  hbnum_std1  hbnum_mean2  \
# 0      2lec     2.857142    6.074556    13.597403    1.939843    12.877123
# 1      2leb     2.857143    5.802325    16.117882    3.131180    13.885115
# 2      4pdb     2.857143    6.186339     8.659341    2.364581    11.131868
# 3      1rkj     2.857142    6.127848    16.370629    2.535955    18.952048
# 4      1wwf     2.857140    6.175579    16.960040    2.966412    14.959041
# 5      5wwg     2.857144    6.344046    11.581419    1.992397     8.847153
# 6      1s40     2.857140    6.175579    16.960040    2.966412    14.959041
# 7      2mki     2.857143    5.442686     6.296703    2.129869    11.741259
# 8      5ytt     2.857140    6.092966     5.522478    1.555418     8.559441
# 9      1wwg     2.857145    6.498764    13.198801    2.709262    12.902098
# 10     5yts     2.857144    6.490460     1.964036    1.445205     4.486513
# 11     2glo     2.857142    6.020716    13.049950    2.036506    12.938062
# 12     4hj5     2.857144    6.552973    11.925075    1.737918    11.998002
# 13     5wzg     2.857141    5.952340    28.909091    2.810130    38.649351
# 14     2b6g     2.857145    6.347354     5.287712    1.871266     6.066933
# 15     2la5     2.857141    6.475605    18.000000    2.480695    20.680320
# 16     3rn2     2.857141    7.035113    16.630370    2.416485     7.082917
# 17     1wwe     2.857142    6.282450    11.814186    2.297425    15.408591
# 18     5ytv     2.857142    6.333032     4.816184    1.265929     5.088911
# 19     5ytx     2.857141    5.900288     3.679321    1.764921     3.098901
# 20     2mkk     2.857143    6.222305    14.158841    2.262880    11.891109
# 21     2kkf     2.857145    6.338872    16.995005    2.077176    13.296703
# 22     2kh9     2.857142    6.339754     4.712288    1.578179     6.740260
# 23     2gkd     2.857143    6.714089     5.129870    1.845457     3.712288
# 24     5wwe     2.857144    6.501107    16.001998    1.900101    11.643357
# 25     2l41     2.857144    6.422024     4.392607    1.475306     5.337662
# 26     1wwd     2.857142    6.368047     9.595405    1.929098     9.180819
# 27     1u63     2.857144    6.338394    13.722278    3.975549    13.028971
# 28     5wzk     2.857144    6.122559    26.501499    2.691283    33.382617
# 29     1u6p     2.857143    6.341429    47.088911    4.220814    47.043956
# 30     1knz     2.857141    5.631103    98.955045    5.063530    83.223776
# 31     1je8     2.857140    6.049513    49.412587    3.029097    26.929071
# 32     3moj     2.857143    6.500905    13.814186    2.719199    18.559441
#
#     hbnum_std2
# 0    13.597403
# 1    16.117882
# 2     8.659341
# 3    16.370629
# 4    16.960040
# 5    11.581419
# 6    16.960040
# 7     6.296703
# 8     5.522478
# 9    13.198801
# 10    1.964036
# 11   13.049950
# 12   11.925075
# 13   28.909091
# 14    5.287712
# 15   18.000000
# 16   16.630370
# 17   11.814186
# 18    4.816184
# 19    3.679321
# 20   14.158841
# 21   16.995005
# 22    4.712288
# 23    5.129870
# 24   16.001998
# 25    4.392607
# 26    9.595405
# 27   13.722278
# 28   26.501499
# 29   47.088911
# 30   98.955045
# 31   49.412587
# 32   13.814186

# %% [markdown]
# # Compile into single file

# %%
X = df_features
Y = df_outputs
Y = Y[["PDB code 1","PDB code 2", "Output"]]
Y["PDB codes"] = Y["PDB code 1"] +" , "+ Y["PDB code 2"]
Y = Y[["PDB codes","Output"]]
Y.set_index("PDB codes",inplace=True)
X["PDB codes"] = X["PDB code 1"] +" , "+ X["PDB code 2"]
X.set_index("PDB codes", inplace=True)
X.drop(["PDB code 1", "PDB code 2"],axis=1,inplace=True)
df, right = X.align(Y,join="right",axis = 0)
df.dropna(inplace=True)
Y = Y[Y.index.isin(df.index)]
df["Output"] = Y["Output"]
df.to_csv("features_outputs.csv")
# Out:
# /var/folders/1l/f_c0h5451133klkyry12ld9h0000gn/T/ipykernel_27950/1653482531.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y["PDB codes"] = Y["PDB code 1"] +" , "+ Y["PDB code 2"]
